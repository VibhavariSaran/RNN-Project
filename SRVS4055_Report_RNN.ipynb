# %% [markdown]
# <a href="https://colab.research.google.com/github/SaumyaRaghuvanshi/RNN-Sentiment-Analysis/blob/main/SRVS4055_Report_RNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **RNN Sentiment Analysis Project Report**
#
# Contributors:
# - Saumya Raghuvanshi
# - Vibhavari Saran

# %% [markdown]
# ## **IMDB Movie Reviews Dataset Description**
#
# - Data Source : Kaggle Link - https://www.kaggle.com/datasets/lakshmi25npathi/imdb-dataset-of-50k-movie-reviews
# - Data Size : 66.21 MB
# - Data Type : The dataset is cross-sectional, containing independent samples (reviews) taken at one point in time. There is no time series component — each record represents an individual opinion, not a sequence of reviews from the same user or over time.
# - Data Dimension : Number of Variables: 2 | Number of Observations: 50,000
# - Variables :
#    - review: The full text of a movie review written by a user
#    - sentiment: The sentiment label for the review — either "positive" or "negative"
# ---
#
# **About the Dataset**
#
# The dataset consists of movie reviews collected from the Internet Movie Database (IMDB). Each record includes the full text of a user-submitted movie review along with a sentiment label indicating whether the review is positive or negative. This dataset is primarily used for natural language processing (NLP) tasks, especially sentiment analysis.
#
# It contains 50,000 individual reviews, evenly balanced between positive and negative sentiments. The data is not time-based or user-tracked — each review stands alone as an independent textual entry, without reference to time or user identity.
#
# This dataset can be used to:
#
# - Train models to classify sentiment in text
#
# - Study linguistic patterns in positive vs. negative reviews
#
# - Benchmark NLP models like RNN, LSTM, BiLSTM, or Transformers
#
# Each record represents a single movie review instance, making the dataset suitable for both educational and real-world sentiment classification tasks.

# %% [markdown]
# ## **Problem Statement**
# Understanding public sentiment toward films is vital for movie producers, streaming platforms, and media analysts. Reviews written by viewers offer rich insights into how a film is perceived — whether it resonates emotionally, delivers on expectations, or falls short. However, analyzing thousands of reviews manually is both time-consuming and subjective.
#
# This project aims to automate sentiment classification of movie reviews using the IMDB Movie Reviews dataset, which contains 50,000 labeled reviews categorized as positive or negative. The goal is to build a machine learning model capable of accurately determining the sentiment expressed in each review.
#
# By implementing a Recurrent Neural Network (RNN), particularly LSTM and BiLSTM architectures, the model leverages the sequential nature of text to understand contextual word relationships. This allows for a more accurate interpretation of sentiment, especially in longer reviews where traditional models may struggle.
#
# The outcome of this project can help in:
#
# - Aggregating audience feedback at scale
#
# - Recommending content based on sentiment trends
#
# - Monitoring reception of newly released films
#
# Ultimately, this analysis supports media platforms and producers in understanding viewer preferences and improving content delivery.

# %% [markdown]
# ## **Project Overview**
#
# The primary objective of this project is to perform sentiment analysis on movie reviews using the IMDB dataset, which contains 50,000 user-generated reviews labeled as either positive or negative. The goal is to develop a Recurrent Neural Network (RNN)-based model capable of accurately classifying the sentiment of a given review.
#
# To improve performance and handle long-range dependencies in text, the project utilizes advanced RNN architectures such as Long Short-Term Memory (LSTM) and Bidirectional LSTM (BiLSTM). These architectures are well-suited for natural language processing tasks and outperform traditional RNNs in retaining contextual meaning over sequences of words.
#
# The project follows a structured approach, including:
#
# - Data cleaning and preprocessing (tokenization, stopword removal, padding, etc.)
#
# - Label encoding and data splitting for training and testing
#
# - Model development using LSTM/BiLSTM layers, with embedding layers and dropout for regularization
#
# - Model training and evaluation using metrics such as accuracy, confusion matrix, and classification report
#
# To visualize the model's learning process, training and validation accuracy/loss graphs are plotted. Additionally, a confusion matrix is used to interpret prediction quality, and incorrectly classified reviews are analyzed for further insight.
#
# This report provides a comprehensive overview of the dataset, preprocessing workflow, model architecture, training strategy, evaluation metrics, and findings from the model’s predictions.

# %% [markdown]
# ## **Analysis of Data**
#
# This section involves understanding and processing the dataset to make it suitable for model training. The key steps include:
#
# 1. Importing the Libraries
#
# To begin our analysis, we first import the necessary libraries required for data preprocessing, model building, and evaluation.
#
# These libraries enable:
#
# - Data Handling: Libraries like NumPy, Pandas , Gdown help in efficient data processing.
# - Visualization: Matplotlib,Seaborn assist in exploring and visualizing data.
# - Deep Learning: Sklearn, tensorflow and its modules are used for building and training the Recurrent Neural Network (RNN) model.
# ---
# 2. IMDB Dataset Pre-processing
#
# - Handling Missing Values
#
#     - Initial data inspection was performed using .head() and .isnull().sum() to check for null values.
#
#     - Although the dataset was mostly clean, any missing values found were explicitly dropped using df.dropna(inplace=True), ensuring only complete entries were used in training.
#
# - Text Tokenization
#
#     - Reviews were tokenized using Keras’s Tokenizer, which converts each review into a sequence of integers representing word indices.
#
#     - The tokenizer was limited to the top 10,000 most frequent words to reduce dimensionality and noise.
#
# - Label Encoding
#
#     - Sentiment labels were encoded into binary format:
#
#        - positive → 1
#
#        - negative → 0
#
# - Padding Sequences
#
#     - All tokenized sequences were padded to a uniform length of 200 tokens using Keras’s pad_sequences.
#
#     - This ensures consistent input shape for RNN-based models and allows the model to process reviews of different lengths.
#
# - Train-Test Split
#
#     - The dataset was split into 80% training and 20% testing using train_test_split.
#
#     - A fixed random_state was used to ensure reproducibility of results.
# ---
# 3. Model Development and Training
#
# a. **Model Architecture**
#
# A Sequential Recurrent Neural Network (RNN) model was developed using TensorFlow and Keras to classify movie reviews from the IMDB dataset into positive or negative sentiments. The architecture consisted of:
#
#   - Embedding Layer:
#
#     - Converts input word indices into dense vector representations.
#
#     - Parameters: input_dim=10000, output_dim=128, input_length=200
#
#     - Helps capture semantic meaning in the reviews.
#
#   - Simple RNN Layer:
#
#     - A recurrent layer with 64 units to capture sequential dependencies in the text.
#
#     - Set return_sequences=False to output only the final hidden state.
#
#   - Dropout Layer:
#
#     - Applied with a rate of 0.5 to prevent overfitting and enhance model generalization.
#
#   - Dense Output Layer:
#
#     - A fully connected layer with a sigmoid activation function to perform binary classification (positive/negative sentiment).
# ---
# b. **Training Parameters**
#
# - Loss Function:
#
#     - binary_crossentropy, suitable for binary sentiment classification tasks.
#
# - Optimizer:
#
#     - Adam, known for its efficient handling of sparse gradients and fast convergence.
#
# - Epochs (The Response may be different as the cells might have run again): The model was trained over 5 epochs.
#
# |Epoch|Training Accuracy|Training Loss|Validation Accuracy|Validation Loss|
# |-----|-----------------|-------------|-------------------|---------------|
# | 1   | 0.6135          | 0.6322      | 0.7542            | 0.5106        |
# | 2   | 0.8383          | 0.3871      | 0.8363            | 0.3841        |
# | 3   | 0.9037          | 0.2551      | 0.6970            | 0.6063        |
# | 4   | 0.8698          | 0.3134      | 0.8274            | 0.5012        |
# | 5   | 0.9637          | 0.1089      | 0.8073            | 0.5748        |
#
#
# - Batch Size:
#
#     - A batch size of 128 was used for efficient training without memory overload.
#
# - Validation Split:
#
#     - 20% of the training data was reserved for validation to monitor model performance during training.
# ---
# c. **Training Process**
#
# - The model was trained using the .fit() function, and training accuracy was tracked across epochs.
#
# - Validation accuracy was also monitored to ensure the model was not overfitting.
#
# - After training, the model was evaluated on the unseen test set using .evaluate(), reporting the final test accuracy.
#
# - The results of the model's predictions were further evaluated using:
#
#     - Classification Report: Shows precision, recall, and F1-score for both classes.
#
#     - Accuracy Graph: Visualizes training and validation accuracy over epochs.
#
# ---
# 4.**Model Evaluation & Observations**
#
# This section summarizes key findings from different stages of the analysis-
#
# 1. **Pre-processing dataset**
#   - Handling Missing Values: Checked for missing values in the review and sentiment columns.The dataset was clean and had no null entries, no imputation was required.
#
#
# 2. **Performance Metrics**
#
# - The trained RNN model was evaluated on the test dataset using accuracy and classification metrics. The results are summarized below:
#
# |Metric	            |     Value |
# |-------------------|-----------|
# |Test Accuracy.     |	 0.8122   |
# |Precision (Class 0)| 	0.81    |
# |Recall (Class 0)	  |   0.82    |
# |F1-Score (Class 0)	|   0.81    |
# |Precision (Class 1)|  	0.81    |
# |Recall (Class 1)	  |   0.81    |
# |F1-Score (Class 1) |	  0.81    |
# |Macro Avg          |Precision:0.81,Recall:0.81,F1-Score:0.81|
# |Weighted Avg	      |Precision:0.81,Recall:0.81,F1-Score:0.81|
#
# These metrics indicate balanced performance across both sentiment classes (positive and negative), with consistent precision and recall values.
#
# 3. **Visualization of Training Performance**
#
# - To monitor the learning behavior and detect any signs of overfitting or underfitting, training and validation accuracy were plotted across all epochs -
#
#     - Train Accuracy steadily increased from 0.61 to 0.96 across the 5 epochs.
#
#     - Validation Accuracy peaked at ~0.83, but showed fluctuations, indicating mild overfitting as training progressed.
#
#
# - This suggests that while the model learned well on the training data, adding regularization (like increased dropout, L2 regularization, or using an LSTM-based model) could help improve generalization.
#
# 4. **Classification Insights**
#
# - A detailed classification report further confirmed model reliability, with a nearly perfect class balance in predictions:
#
#     - The model performs equally well on both positive and negative sentiment classes.
#
#     - Slight variations between train and validation accuracy hint that model complexity might need tuning for better generalization.
#
# 5. **Summary Results Table**
#
# | Metric              | Value  |
# |---------------------|--------|
# | Total Reviews      | 10000  |
# | Correct Predictions | 8122 |
# | Incorrect Predictions | 1878 |
# | Model Accuracy     | 81.22% |

# %% [markdown]
# ![Screenshot 2025-04-08 at 12.45.17 AM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-04-08 at 12.45.32 AM.png](data:image/png;base64,...)

# %% [markdown]
# ### **Overall Assessment**
#
# The project demonstrates a successful implementation of an RNN-based sentiment analysis model. Key observations:
#
# - Model Performance Overview:
#
#     - The model achieves 81.22% accuracy on the IMDB test set, indicating solid sentiment classification capabilities.
#
#     - Precision, recall, and F1-scores are balanced at 0.81 across both sentiment classes, reflecting consistently strong performance across positive and negative reviews.
#
#     - The slight performance dip in validation accuracy during training suggests some variability, likely due to fluctuations in review length and style across samples.
#
# ---
# - Confidence and Generalization:
#
#     - The model's predictions show balanced confidence across sentiment classes, supported by nearly equal performance for both positive and negative reviews.
#
#     - Misclassifications (18.78%) appear reasonably low for a binary classification task based on natural language, showing good generalization to unseen IMDB reviews.
# ---
# - Training Insights:
#
#     - The training accuracy improved steadily across 5 epochs, reaching 96.37%, while the final validation accuracy settled around 80.73%.
#
#     - The divergence between training and validation accuracy in later epochs suggests mild overfitting, which could be mitigated with dropout regularization or more data augmentation.

# %% [markdown]
# #### To enhance performance beyond the current accuracy, we are now implementing the model using LSTM and BiLSTM architectures. These advanced recurrent models are better at capturing long-term dependencies in text data and are expected to yield higher generalization and improved sentiment detection.

# %% [markdown]
# ### **Improving the accuracy of the model using LSTM & BiLSTM**

# %% [markdown]
# ### **Enhancing Sentiment Analysis Accuracy Through Advanced Tokenization**
#
# #### **Objective**
#
# The goal is to improve the accuracy of an RNN-based sentiment analysis model by refining the input data through advanced tokenization techniques such as:
#
# - Text cleaning (removal of stopwords, special characters)
#
# - Lemmatization (reducing words to their base/root form)
#
# ---
#
# #### **Why Use Advanced Tokenization?**
#
# - The default tokenizer in Keras is efficient but basic, and may not handle:
#
#     - Redundant or noisy words (e.g., "the", "is", "@", punctuation)
#
#     - Variations of the same word (e.g., "running", "ran", "runs")
#
# - By applying text cleaning and lemmatization, we:
#
#     - Reduce vocabulary size, helping the model learn more effectively
#
#     - Focus on meaningful words, improving signal-to-noise ratio
#
#     - Ensure semantic consistency (e.g., treating "good", "better", and "best" in the same context)
#
# This results in more consistent and generalizable input, which directly improves training dynamics and final accuracy.
#
# ---
#
# #### **Why Improve Accuracy?**
# - Better User Experience: Higher accuracy means more reliable sentiment predictions, which is essential in applications like recommendation engines, social media monitoring, or customer feedback analysis.
#
# - Trust & Credibility: Business decisions based on sentiment predictions require high confidence in the results.
#
# - Model Reliability: A more accurate model is better at handling unseen data, especially from different domains (like movie reviews, product feedback, etc.).
#
# - Transferability: A well-optimized model on one dataset (e.g., IMDB) can be effectively reused or fine-tuned on others (e.g., Metacritic, Amazon), saving time and resources.
#
# ---
# #### **Summary**
# Improving tokenization enhances the quality of input data, which leads to better model learning and improved performance. Higher accuracy is crucial for building trustworthy and effective real-world NLP systems.

# %% [markdown]
# ### **Analysis of Data**
#
# This section involves understanding and processing the dataset to make it suitable for model training. The key steps include:
#
# 1.**Importing the Libraries**
#
# To begin the sentiment analysis, the following Python libraries were imported:
#
# - NLTK: For text preprocessing such as tokenization, stopword removal, and lemmatization.
#
# - Gdown: To download the IMDB dataset directly from Google Drive.
#
# - Pandas, NumPy: For efficient data manipulation and numerical operations.
#
# - Sklearn: For data splitting and label encoding.
#
# - TensorFlow & Keras: For building and training the LSTM-based deep learning model.
#
# ---
#
# 2.**IMDB Dataset Preprocessing**
#
# 1. Handling Missing Values
#
# - Initial data inspection using .head() and .isnull().sum() revealed that the dataset was largely clean.
#
# - Any missing values were dropped using df.dropna(inplace=True) to ensure the quality of inputs.
#
# 2. Text Cleaning and Lemmatization
#
# - All the text was:
#
#     - Converted to lowercase
#
#     - Stripped of punctuation and non-alphabetic characters
#
#     - Tokenized using NLTK’s word_tokenize
#
#     - Cleaned by removing stopwords and applying lemmatization via WordNetLemmatizer
#
#     - Stored the cleaned text in a new column: cleaned_review
#
# 3. Label Encoding
# - Sentiment values were converted into binary labels using LabelEncoder:
#
#     - positive → 1
#
#     - negative → 0
#
# 4. Tokenization and Padding
#
# - Keras’s Tokenizer was used to convert text into sequences of integers (word indices), limiting the vocabulary to the top 10,000 words.
#
# - All sequences were padded to a fixed length of 200 tokens using pad_sequences.
#
# 5. Train-Test Split
#
# - The dataset was split with 80% for training and 20% for testing.
#
# ---
#
# 3. **Model Development and Training**
#
# a. Model Architecture
#
# - A Sequential LSTM model was built using Keras:
#
#     - Embedding : input_dim=10000, output_dim=100, input_length=200,
# Transforms input word indices into dense vector embeddings.
#
#     - LSTM : units=128, return_sequences=False ,
# Captures sequential patterns and dependencies in the text data.
#
#     - Dropout : 	rate=0.5,
# Helps mitigate overfitting by randomly dropping neurons during training.
#
#     - Dense : units=1, activation='sigmoid',
# Outputs a probability score for binary sentiment classification.
#
# b. Training Parameters
#
# - Loss Function:
#
#     - binary_crossentropy, suitable for binary sentiment classification tasks.
#
# - Optimizer:
#
#     - Adam, known for its efficient handling of sparse gradients and fast convergence.
#
# - Epochs(The Response may be different as the cells might have run again) : The model was trained over 10 epochs.
#
# |Epoch|Training Accuracy|Training Loss|Validation Accuracy|Validation Loss|
# |-----|-----------------|-------------|-------------------|---------------|
# | 1   | 0.5153          | 0.6931      | 0.5274            | 0.6825        |
# | 2   | 0.5417          | 0.6850      | 0.5466            | 0.6626        |
# | 3   | 0.5921          | 0.6202      | 0.8461            | 0.3868        |
# | 4   | 0.8711          | 0.3350      | 0.8704            | 0.3309        |
# | 5   | 0.9305          | 0.2042      | 0.8775            | 0.3378        |
# | 6   | 0.9590          | 0.1358      | 0.8748            | 0.3735        |
# | 7   | 0.9741          | 0.0936      | 0.8618            | 0.4410        |
#
#
# - Batch Size:
#
#     - A batch size of 64 was used for efficient training without memory overload.
#
# - Validation Split:
#
#     - 20% of the training data was reserved for validation to monitor model performance during training.
#
# ---
#
# 4.**Model Evaluation & Observations**
#
# 1. **Visualization of Training Performance**
#
# - To evaluate the model's learning behavior and potential overfitting/underfitting, training and validation metrics were observed over 7 epochs:
#
#     - Training Accuracy improved steadily from 51.53% in epoch 1 to 97.41% by epoch 7.
#
#     - Validation Accuracy peaked at 87.74% around epoch 5 but showed slight fluctuations afterward (dropping to 86.18% by epoch 7), indicating minor overfitting.
#
#     - Loss Values followed a decreasing trend: training loss dropped from 0.6931 to 0.0936, while validation loss went from 0.6825 to 0.4410.
#
# These trends suggest that while the model effectively learned from the training data, mild overfitting was observed toward the end. Incorporating early stopping, higher dropout, or further regularization could enhance generalization.
#
# 2. **Classification Insights**
#
# - The model shows reliable performance across test data, as reflected in the prediction metrics:
#
#     - Test Accuracy reached 87.26%, showing good generalization to unseen data.
#
#     - Out of 10,000 test reviews, the model made:
#
#       - 8,726 correct predictions
#
#       - 1,274 incorrect predictions
#
# The consistent performance across both training and testing sets suggests a balanced classification, likely indicating the model handles both sentiment classes (positive/negative) effectively.
#
# 3. **Summary Results Table**
#
# | Metric              | Value  |
# |---------------------|--------|
# | Total Reviews      | 10000  |
# | Correct Predictions | 8726 |
# | Incorrect Predictions | 1274 |
# | Model Accuracy     | 87.26% |

# %% [markdown]
# ![Screenshot 2025-04-08 at 1.57.41 AM.png](data:image/png;base64,...)

# %% [markdown]
# ### **Enhancing Sentiment Analysis with Stacked BiLSTM Layers**
# **Objective**
#
# - The goal is to improve the accuracy of an RNN-based sentiment analysis model by enhancing its architecture through stacking multiple Bidirectional LSTM (BiLSTM) layers.
#
# - Bidirectional LSTMs process sequences in both forward and backward directions, allowing the model to understand context from both past and future tokens—which is especially helpful in understanding the sentiment conveyed in natural language.
# ---
#
# **Why Use Stacked BiLSTM Layers?**
#
# - A single BiLSTM layer captures useful sequential patterns, but it may not fully exploit the depth of semantic structures in complex reviews. Stacking multiple BiLSTM layers provides the following benefits:
#
#     - Deeper Contextual Learning:
# Each additional layer captures increasingly abstract features from the sequence, leading to better understanding of nuanced sentiments.
#
#     - Hierarchical Feature Extraction:
# Lower layers can capture basic word relationships, while higher layers can focus on phrase- or sentence-level sentiment patterns.
#
#     - Improved Sequence Modeling:
# With multiple BiLSTM layers, the model becomes more robust in detecting long-range dependencies—key for sentiment phrases like "Although the start was slow, the movie ended brilliantly."
#
# This architectural improvement results in better generalization and higher accuracy on unseen reviews.

# %% [markdown]
# ### **Analysis of Data**
#
# This section involves understanding and processing the dataset to make it suitable for model training. The key steps include:
#
# 1.**Importing the Libraries**
#
# - Libraries used were same as the ones used in LSTM
# ---
#
# 2.**IMDB Dataset Preprocessing**
#
# - Pre-processing steps were same as the ones in LSTM
# ---
#
# 3.**Model Development and Training**
#
# a. Model Architecture
#
# A Bidirectional Long Short-Term Memory (BiLSTM) neural network was developed using TensorFlow and Keras to classify movie reviews from the IMDB dataset as either positive or negative. The architecture is designed to capture context from both past and future tokens in a sentence, which is especially valuable in sentiment analysis.
#
# - The model consists of the following layers:
#
#     - Embedding Layer:
#
#        - Transforms word indices into dense vector representations.
#
#        - Parameters: input_dim=vocab_size, output_dim=100, input_length=max_len
#
#        - Purpose: Encodes the semantic meaning of each word.
#
# - Bidirectional LSTM Layers:
#
#     - First Layer: Bidirectional(LSTM(128, return_sequences=True))
# Captures forward and backward context for each time step.
#
#     - Second Layer: Bidirectional(LSTM(64))
# Outputs the combined context vector of the sequence.
#
# - Dropout Layers:
#
#     - Dropout rate of 0.3 after each LSTM block to prevent overfitting.
#
# - Dense Output Layer:
#
#     - A fully connected layer with sigmoid activation for binary classification.
#
# This layered approach allows the model to better understand sentiment-bearing phrases in both directions of the review.
#
# b. Training Parameters
#
# - Loss Function: binary_crossentropy, ideal for binary classification tasks.
#
# - Optimizer: Adam optimizer with a learning rate of 0.001, known for its adaptive learning and faster convergence.
#
# - Epochs: The model was trained for 7 epochs, with early stopping used to prevent overfitting.
#
# |Epoch|Training Accuracy|Training Loss|Validation Accuracy|Validation Loss|
# |-----|-----------------|-------------|-------------------|---------------|
# | 1   | 0.7069          | 0.5702      | 0.8393            | 0.3989        |
# | 2   | 0.8467          | 0.3791      | 0.8655            | 0.3187        |
# | 3   | 0.8934          | 0.2778      | 0.8575            | 0.3466        |
# | 4   | 0.9079          | 0.2395      | 0.8864            | 0.2751        |
# | 5   | 0.9302          | 0.1925      | 0.8703            | 0.3204        |
# | 6   | 0.9439          | 0.1601      | 0.8833            | 0.2929        |
# | 7   | 0.9587          | 0.1247      | 0.8754            | 0.3613        |
#
# - Test Accuracy:
#
#     - Final test accuracy achieved: 88.45%
#
# - Batch Size:
#
#     - 64, offering a balance between training speed and stability.
#
# - Validation Data:
#
#     - 20% of the data was used for validation during training.
#
# c. Training Process
# - Training was conducted using the model.fit() method, with accuracy and loss tracked across epochs.
#
# - EarlyStopping was implemented with patience=3 to prevent overfitting by halting training when validation loss stops improving.
#
# - The model's performance was further evaluated using:
#
#     - Classification Report:
#
#        - Precision: Negative: 0.90, Positive: 0.87
#
#        - Recall: Negative: 0.86, Positive: 0.91
#
#        - F1-Score: Negative: 0.88, Positive: 0.89
#
#        - Overall Accuracy: 0.89
#
# - Learning Curves:
#
#     - The training accuracy showed a steady increase.
#
#     - Validation accuracy peaked around epoch 4–6, indicating good generalization.
#
#     - Training loss decreased consistently, while validation loss showed some fluctuation, suggesting slight overfitting in later epochs.
#
# ---
#
# 4.**Model Evaluation & Observations**
#
# 1. **Performance Metrics**
# - The trained BiLSTM model was evaluated on the test dataset using accuracy and classification metrics. The results are summarized below:
#
# |Metric	            |     Value |
# |-------------------|-----------|
# |Test Accuracy      |	 0.8864   |
# |Precision (Class 0)| 	0.90    |
# |Recall (Class 0)	  |   0.88    |
# |F1-Score (Class 0)	|   0.86    |
# |Precision (Class 1)|  	0.87    |
# |Recall (Class 1)	  |   0.91    |
# |F1-Score (Class 1) |	  0.89    |
# |Macro Avg          |Precision:0.89,Recall:0.89,F1-Score:0.89|
# |Weighted Avg	      |Precision:0.89,Recall:0.89,F1-Score:0.89|
#
# These metrics reflect strong and balanced performance across both sentiment classes (positive and negative), with slightly better recall for positive sentiment predictions.
#
# 2. **Visualization of Training Performance**
#
# - To monitor learning behavior and detect signs of overfitting or underfitting, training and validation metrics were visualized:
#
#     - Train Accuracy increased steadily from ~0.75 to ~0.96 over 7 epochs.
#
#     - Validation Accuracy peaked around 0.88, though it fluctuated in the later epochs, indicating possible mild overfitting.
#
#     - Train Loss continuously declined, whereas Validation Loss began to increase after epoch 3.
#
# These trends suggest that while the model learned effectively, introducing stronger regularization (e.g., more dropout, early stopping, or L2 penalties) may help further improve generalization.
#
# 3. **Classification Insights**
#
# - The confusion matrix and classification report confirm the model's reliable performance:
#
#     - High counts of true positives and true negatives suggest good discrimination between sentiment classes.
#
#     - Slightly higher false negatives (464) than false positives (672) indicate the model is slightly more conservative when predicting positive sentiment.
#
#     - With balanced class-wise precision, recall, and F1-scores, the BiLSTM model demonstrates consistent prediction quality across sentiment labels.
#
# 4. **Summary Results Table**
#
# | Metric              | Value  |
# |---------------------|--------|
# | Total Reviews      | 10000  |
# | Correct Predictions | 8864 |
# | Incorrect Predictions | 1136 |
# | Model Accuracy     | 88.64% |

# %% [markdown]
# ![Screenshot 2025-04-08 at 2.48.27 AM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-04-08 at 2.48.50 AM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-04-08 at 2.49.06 AM.png](data:image/png;base64,...)

# %% [markdown]
# ### **Overall Assessment**
#
# The project showcases an effective implementation of a BiLSTM-based sentiment analysis model, enhancing sequence understanding through bidirectional context. Key observations:
#
# - Model Performance Overview:
#
#     - The model achieves 88.64% accuracy on the IMDB test set, indicating a high level of accuracy in distinguishing sentiment polarity.
#
#     - Precision, recall, and F1-scores are strong and balanced, with macro-average F1-score reaching 0.89, showing reliable performance across both positive and negative classes.
#
#     - The improved recall for the positive class (0.91) highlights the model’s strength in identifying favorable sentiment, which is often critical in customer feedback analysis.
# ---
# - Confidence and Generalization:
#
#     - Predictions demonstrate well-calibrated confidence across sentiment categories, with reduced misclassification compared to simpler RNN architectures.
#
#     - A low error rate (~11.36%) on the test set confirms the model’s ability to generalize well to new, unseen movie reviews despite natural language variability.
#
# ---
# - Training Insights:
#
#     - Training accuracy increased steadily to 96.37% over 5 epochs, and validation accuracy peaked at 87.71%, maintaining consistency through training.
#
#     - While there is slight overfitting indicated by the gap between training and validation accuracy, it remains minor and manageable—suggesting that the model retains good generalization while learning complex patterns.
#
#     - The application of dropout layers and two stacked BiLSTM units likely contributed to better feature extraction and robustness in classification.

# %% [markdown]
# ## **Managerial Insights & Recommendations**
#
# The sentiment analysis project effectively applied sequential deep learning models to classify movie reviews from the IMDB dataset. The BiLSTM model outperformed standard RNN and LSTM architectures, achieving 88.64% test accuracy with balanced performance metrics. Based on these results, the following recommendations are proposed for business and technical stakeholders to further enhance model performance and deployment readiness.
#
# 1.**Key Insights:**
#
# - BiLSTM Outperforms Simple RNN:
#
#     - The BiLSTM model achieved 88.64% test accuracy, significantly outperforming the basic RNN model (81.22%).
#
#     - It also delivered higher precision, recall, and F1-scores, showing a more reliable understanding of both positive and negative sentiments.
#
# - Balanced Sentiment Prediction:
#
#     - Both models showed balanced performance across sentiment classes, reducing the risk of bias toward a particular label.
#
#     - This is important for applications like review moderation or customer satisfaction analytics, where fairness is crucial.
#
# - Mild Overfitting Observed:
#
#     - While training accuracy was very high in both models (up to 96.37%), validation metrics showed slight overfitting, more noticeable in the RNN model.
#
#     - BiLSTM showed better generalization, but still room exists for further improvement through regularization techniques.
#
# 2.**Strategic Recommendations:**
#
# - Adopt BiLSTM for Production Use: Given its superior accuracy and generalization, BiLSTM should be the preferred model for deployment in sentiment-driven applications (e.g., product reviews, customer support systems).
#
# - Incorporate Regularization for Long-Term Robustness: Add L2 regularization, early stopping, and/or increased dropout to reduce overfitting, especially in longer training scenarios or real-time applications.
#
# - Utilize Pre-trained Embeddings: Switching from randomly initialized embeddings to pre-trained word embeddings (e.g., GloVe, FastText) may boost model accuracy and accelerate convergence.
#
# - Explore Attention Mechanisms:
#  Integrating attention layers can help the model focus on the most relevant words in a sentence, which can be especially useful in long or nuanced reviews.
#
# - Monitor and Refresh with Real-time Data: Periodically retrain the model with fresh reviews to adapt to changing language patterns or slang in user-generated content.
#
# - Deploy as Part of a Feedback System: Integrate the model into business tools such as CRM platforms, movie platforms, or customer review dashboards for real-time sentiment tracking.
# ---
#
# **Future Opportunities:**
#
# - Multi-class Sentiment: Expand beyond binary classification to detect nuanced sentiments (e.g., neutral, mixed, sarcastic).
#
# - Cross-domain Transfer: Apply the trained model to other domains (e.g., Amazon product reviews or app feedback) with domain adaptation techniques.
#
# - Model Explainability: Implement tools like LIME or SHAP to provide interpretability of model decisions for trust and compliance.

# %% [markdown]
# ## **Conclusion**
#
# This project successfully demonstrated the application of deep learning—specifically Recurrent Neural Networks (RNN) and Bidirectional LSTM (BiLSTM)—for sentiment analysis on the IMDB movie review dataset. The models were evaluated based on classification performance, with the BiLSTM model significantly outperforming the traditional RNN in both accuracy and generalization.
#
# The BiLSTM model achieved 88.64% test accuracy, showcasing its ability to effectively capture contextual sentiment patterns in user reviews. Its bidirectional nature allowed it to process information from both past and future word sequences, resulting in a more comprehensive understanding of sentence structure and sentiment cues.
#
# While both models exhibited strong training performance, mild overfitting highlighted the need for regularization and further optimization. Despite this, the results indicate a solid foundation for building scalable and reliable sentiment analysis tools.
#
# This work paves the way for real-world deployment in areas like product feedback analysis, customer experience tracking, and content moderation. With further tuning—such as incorporating pre-trained embeddings, attention mechanisms, and model explainability features—this system can evolve into a powerful NLP-based sentiment analysis engine for broader applications.

# %% [markdown]
# ### **ANALYSIS**

# %%
import pandas as pd
import numpy as np
import gdown
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, Dense, Dropout
from tensorflow.keras.utils import to_categorical

# Load Dataset
# Google Drive file ID for the dataset
file_id = '1xyjfdyooXbUSSNmi8AlALLZLZ8O9AM1Z'
csv_path = 'IMDB Dataset.csv'  # Adjusted filename for clarity

# Download the CSV file from Google Drive
gdown.download(f'https://drive.google.com/uc?id={file_id}', csv_path, quiet=False)

df = pd.read_csv(csv_path)

# Inspect data
print(df.head())
print(df.isnull().sum())

# Drop missing values (if any)
df.dropna(inplace=True)

# Label Encoding: positive -> 1, negative -> 0
df['sentiment'] = df['sentiment'].map({'positive': 1, 'negative': 0})

# Tokenization
max_words = 10000  # Top 10k words
tokenizer = Tokenizer(num_words=max_words)
tokenizer.fit_on_texts(df['review'])
sequences = tokenizer.texts_to_sequences(df['review'])

# Padding Sequences
max_len = 200  # You can experiment with this
X = pad_sequences(sequences, maxlen=max_len)

# Target variable
y = df['sentiment'].values

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=5504055)

# Model Building
model = Sequential()
model.add(Embedding(input_dim=max_words, output_dim=128, input_length=max_len))
model.add(SimpleRNN(units=64, return_sequences=False))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))

# Compile
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train
history = model.fit(X_train, y_train, epochs=5, batch_size=128, validation_split=0.2)

# Evaluate
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {accuracy:.4f}")

# Classification Report
y_pred = (model.predict(X_test) > 0.5).astype(int)
print(classification_report(y_test, y_pred))

# Plot training history
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend()
plt.show()
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1xyjfdyooXbUSSNmi8AlALLZLZ8O9AM1Z
# To: /content/IMDB Dataset.csv
# 100%|██████████| 66.2M/66.2M [00:00<00:00, 179MB/s]
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive
# review       0
# sentiment    0
# dtype: int64
# Epoch 1/5
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - accuracy: 0.6135 - loss: 0.6322 - val_accuracy: 0.7542 - val_loss: 0.5106
# Epoch 2/5
# ...

# %%
#Testing the model on test data

from tabulate import tabulate

# Create reverse mapping to decode tokenized text
reverse_word_index = {value: key for key, value in tokenizer.word_index.items()}

def decode_review(sequence):
    """Convert token sequence back to text."""
    return ' '.join([reverse_word_index.get(i, '?') for i in sequence if i != 0])

# Number of test samples to display
N = 10

# Select first N samples from test data
sample_sequences = X_test[:N]
sample_true_labels = y_test[:N]

# Decode the reviews
decoded_reviews = [decode_review(seq) for seq in sample_sequences]

# Predict sentiments
sample_probs = model.predict(sample_sequences)
sample_preds = (sample_probs > 0.5).astype(int).flatten()
confidences = sample_probs.flatten()

# Create result DataFrame
result_df = pd.DataFrame({
    'Review': decoded_reviews,
    'Actual Sentiment': ['positive' if label == 1 else 'negative' for label in sample_true_labels],
    'Predicted Sentiment': ['positive' if pred == 1 else 'negative' for pred in sample_preds],
    'Confidence Score': np.round(confidences, 4)
})

# Display as a well-formatted table
print("\n📊 Sentiment Analysis Results (Sample of Test Set):\n")
print(tabulate(result_df, headers='keys', tablefmt='grid', showindex=False))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step
#
# 📊 Sentiment Analysis Results (Sample of Test Set):
#
# ...

# %%
from tabulate import tabulate

# Step 1: Predict on entire test set
y_probs = model.predict(X_test)
y_preds = (y_probs > 0.5).astype(int).flatten()
confidences = y_probs.flatten()

# Step 2: Evaluate predictions
total = len(y_test)
correct = np.sum(y_preds == y_test)
wrong = total - correct
accuracy = correct / total

# Step 3: Display summary table
summary_table = [
    ['Total Records', total],
    ['Correct Predictions', correct],
    ['Wrong Predictions', wrong],
    ['Accuracy', f"{accuracy * 100:.2f}%"]
]

print("\n📊 Prediction Summary:\n")
print(tabulate(summary_table, headers=['Metric', 'Value'], tablefmt='fancy_grid'))
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step
#
# 📊 Prediction Summary:
#
# ╒═════════════════════╤═════════╕
# │ Metric              │ Value   │
# ╞═════════════════════╪═════════╡
# │ Total Records       │ 10000   │
# ├─────────────────────┼─────────┤
# │ Correct Predictions │ 8122    │
# ├─────────────────────┼─────────┤
# │ Wrong Predictions   │ 1878    │
# ├─────────────────────┼─────────┤
# │ Accuracy            │ 81.22%  │
# ╘═════════════════════╧═════════╛

# %%
#Code to show wrongly predicted sentiments

#Identify wrongly predicted samples
wrong_indices = np.where(y_preds != y_test)[0]

# Decode reviews
reverse_word_index = {v: k for k, v in tokenizer.word_index.items()}
def decode_review(seq):
    return ' '.join([reverse_word_index.get(i, '?') for i in seq if i != 0])

# Select N wrongly predicted samples to display
N = 10  # You can change this to see more
sample_wrong_indices = wrong_indices[:N]
wrong_reviews = [decode_review(X_test[i]) for i in sample_wrong_indices]
true_labels = ['positive' if y_test[i] == 1 else 'negative' for i in sample_wrong_indices]
predicted_labels = ['positive' if y_preds[i] == 1 else 'negative' for i in sample_wrong_indices]
confidence_scores = [confidences[i] for i in sample_wrong_indices]

# Build wrong predictions DataFrame
wrong_df = pd.DataFrame({
    'Review': wrong_reviews,
    'Actual Sentiment': true_labels,
    'Predicted Sentiment': predicted_labels,
    'Confidence Score': np.round(confidence_scores, 4)
})

# Show table
print("\n❌ Wrongly Predicted Samples:\n")
print(tabulate(wrong_df, headers='keys', tablefmt='grid', showindex=False))
# Out:
# ❌ Wrongly Predicted Samples:
#
# ...

# %% [markdown]
# ### **Improving the accuracy of the model using LSTM**

# %%
#Improving the accuracy of the model using LSTM
import nltk
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('wordnet')
import gdown
import pandas as pd
import numpy as np
import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# Load dataset
# Google Drive file ID for the dataset
file_id = '1xyjfdyooXbUSSNmi8AlALLZLZ8O9AM1Z'
csv_path = 'IMDB Dataset.csv'  # Adjusted filename for clarity

# Download the CSV file from Google Drive
gdown.download(f'https://drive.google.com/uc?id={file_id}', csv_path, quiet=False)

df = pd.read_csv(csv_path)  # Update path as needed

# Clean and preprocess the text
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

def clean_text(text):
    text = text.lower()
    text = re.sub(r'[^a-z\s]', '', text)
    tokens = word_tokenize(text)
    tokens = [lemmatizer.lemmatize(w) for w in tokens if w not in stop_words]
    return ' '.join(tokens)

df['cleaned_review'] = df['review'].astype(str).apply(clean_text)

# Encode labels
label_encoder = LabelEncoder()
df['label'] = label_encoder.fit_transform(df['sentiment'])  # positive = 1, negative = 0

# Tokenize text
vocab_size = 10000
max_len = 200
tokenizer = Tokenizer(num_words=vocab_size, oov_token="<OOV>")
tokenizer.fit_on_texts(df['cleaned_review'])

sequences = tokenizer.texts_to_sequences(df['cleaned_review'])
padded_sequences = pad_sequences(sequences, maxlen=max_len, padding='post')

# Train/test split
X_train, X_test, y_train, y_test = train_test_split(
    padded_sequences, df['label'], test_size=0.2, random_state=42
)

# Build LSTM model
embedding_dim = 100

model = Sequential()
model.add(Embedding(input_dim=vocab_size, output_dim=embedding_dim, input_length=max_len))
model.add(LSTM(128, return_sequences=False))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()

# Callbacks
early_stop = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
checkpoint = ModelCheckpoint('best_model.h5', save_best_only=True)

# Train model
history = model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=10,
    batch_size=64,
    callbacks=[early_stop, checkpoint],
    verbose=1
)

# Evaluate
loss, accuracy = model.evaluate(X_test, y_test)
print(f"\n✅ Test Accuracy: {accuracy * 100:.2f}%")
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Downloading...
# From: https://drive.google.com/uc?id=1xyjfdyooXbUSSNmi8AlALLZLZ8O9AM1Z
# To: /content/IMDB Dataset.csv
# 100%|██████████| 66.2M/66.2M [00:00<00:00, 68.7MB/s]
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ...

# %%
#Testing the model on the test data
from tabulate import tabulate

# Predict probabilities
y_probs = model.predict(X_test)
y_preds = (y_probs > 0.5).astype(int).flatten()
confidences = y_probs.flatten()

# Decode sentiment labels
inv_label_map = {0: 'negative', 1: 'positive'}

# Get original test reviews from the dataframe
X_test_texts = df.iloc[y_test.index]['review'].tolist() if isinstance(y_test, pd.Series) else df['review'].iloc[X_test.shape[0]*-1:].tolist()
actual_sentiments = [inv_label_map[y] for y in y_test]
predicted_sentiments = [inv_label_map[pred] for pred in y_preds]

# Build results DataFrame
results_df = pd.DataFrame({
    'Review': X_test_texts,
    'Actual Sentiment': actual_sentiments,
    'Predicted Sentiment': predicted_sentiments,
    'Confidence Score': np.round(confidences, 4)
})

# Show a sample of results
print("\n📝 Sample Predictions Table:\n")
print(tabulate(results_df.head(10), headers='keys', tablefmt='fancy_grid', showindex=False))
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step
#
# 📝 Sample Predictions Table:
#
# ...

# %%
# Summary of the predictions and identifying the wrongly predicted sentiments
# Step 1: Calculate prediction summary
total = len(y_test)
correct = np.sum(y_preds == y_test)
wrong = total - correct
accuracy = correct / total * 100

summary_table = [
    ['Total Records', total],
    ['Correct Predictions', correct],
    ['Wrong Predictions', wrong],
    ['Accuracy', f"{accuracy:.2f}%"]
]

print("\n📊 Prediction Summary:\n")
print(tabulate(summary_table, headers=['Metric', 'Value'], tablefmt='fancy_grid'))

# Step 2: Show wrongly predicted samples
wrong_indices = np.where(y_preds != y_test)[0]

# Select N wrongly predicted samples to show
N = 10  # change to view more
wrong_reviews = [X_test_texts[i] for i in wrong_indices[:N]]
actual_wrong = [actual_sentiments[i] for i in wrong_indices[:N]]
predicted_wrong = [predicted_sentiments[i] for i in wrong_indices[:N]]
conf_wrong = [confidences[i] for i in wrong_indices[:N]]

# Build DataFrame
wrong_df = pd.DataFrame({
    'Review': wrong_reviews,
    'Actual Sentiment': actual_wrong,
    'Predicted Sentiment': predicted_wrong,
    'Confidence Score': np.round(conf_wrong, 4)
})

print("\n❌ Wrongly Predicted Samples:\n")
print(tabulate(wrong_df, headers='keys', tablefmt='fancy_grid', showindex=False))
# Out:
# 📊 Prediction Summary:
#
# ╒═════════════════════╤═════════╕
# │ Metric              │ Value   │
# ╞═════════════════════╪═════════╡
# │ Total Records       │ 10000   │
# ├─────────────────────┼─────────┤
# │ Correct Predictions │ 8726    │
# ├─────────────────────┼─────────┤
# │ Wrong Predictions   │ 1274    │
# ├─────────────────────┼─────────┤
# │ Accuracy            │ 87.26%  │
# ╘═════════════════════╧═════════╛
#
# ❌ Wrongly Predicted Samples:
#
# ...

# %% [markdown]
# ### **Further improving the accuracy of the model using BiLSTM**

# %%
# Further improving the accuracy of the model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Bidirectional, LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam

# BiLSTM model architecture
model = Sequential()
model.add(Embedding(input_dim=vocab_size, output_dim=100, input_length=max_len))
model.add(Bidirectional(LSTM(128, return_sequences=True)))
model.add(Dropout(0.3))
model.add(Bidirectional(LSTM(64)))
model.add(Dropout(0.3))
model.add(Dense(1, activation='sigmoid'))

# Compile model
model.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate=0.001), metrics=['accuracy'])

# Print model summary
model.summary()

# Add early stopping to prevent overfitting
early_stop = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# Train the model
history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=10,
    batch_size=64,
    callbacks=[early_stop]
)

# Evaluate model
loss, accuracy = model.evaluate(X_test, y_test)
print(f"\n📊 BiLSTM Test Accuracy: {accuracy * 100:.2f}%")
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding_5 (Embedding)              │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional_4 (Bidirectional)      │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_7 (Dropout)                  │ ?                           │               0 │
# ...

# %%
#Testing the model on test data
import numpy as np
import pandas as pd
from tabulate import tabulate

# Predict probabilities
y_pred_probs = model.predict(X_test)
y_preds = (y_pred_probs > 0.5).astype(int).reshape(-1)

# Convert to human-readable values
actual_sentiments = ['Positive' if label == 1 else 'Negative' for label in y_test]
predicted_sentiments = ['Positive' if pred == 1 else 'Negative' for pred in y_preds]
confidences = y_pred_probs.reshape(-1)

# Reconstruct reviews from tokenized inputs (if you have tokenizer)
# WARNING: Only do this if you kept the original text or can decode tokens
reverse_word_map = dict(map(reversed, tokenizer.word_index.items()))

def decode_review(encoded_review):
    return ' '.join([reverse_word_map.get(i, '?') for i in encoded_review if i != 0])

X_test_texts = [decode_review(seq) for seq in X_test[:10]]  # limit for display

# Create prediction table
results_df = pd.DataFrame({
    'Review': X_test_texts,
    'Actual Sentiment': actual_sentiments[:10],
    'Predicted Sentiment': predicted_sentiments[:10],
    'Confidence Score': np.round(confidences[:10], 4)
})

# Display results as a table
print("\n📊 Sample Predictions (BiLSTM):\n")
print(tabulate(results_df, headers='keys', tablefmt='fancy_grid', showindex=False))
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step
#
# 📊 Sample Predictions (BiLSTM):
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

# Predictions
y_pred_probs = model.predict(X_test)
y_preds = (y_pred_probs > 0.5).astype(int).reshape(-1)

# ----------------------------
# 📌 1. Confusion Matrix
# ----------------------------
cm = confusion_matrix(y_test, y_preds)
labels = ['Negative', 'Positive']

plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt='d', xticklabels=labels, yticklabels=labels, cmap="Blues")
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# ----------------------------
# 📌 2. Classification Report
# ----------------------------
print("\n🔍 Classification Report:")
print(classification_report(y_test, y_preds, target_names=labels))

# ----------------------------
# 📌 3. Training History Graphs
# ----------------------------
# Make sure you saved model.fit() as `history`
plt.figure(figsize=(12, 4))

# Accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# ----------------------------
# 📌 4. Incorrect Predictions Table
# ----------------------------
wrong_indexes = np.where(y_preds != y_test)[0]

# Convert y_test to a NumPy array if it's a Pandas Series
y_test_array = np.array(y_test)

# Decode the wrongly predicted reviews (if needed)
X_wrong_texts = [decode_review(X_test[int(i)]) for i in wrong_indexes[:10]]
actual_wrong = ['Positive' if y_test_array[int(i)] == 1 else 'Negative' for i in wrong_indexes[:10]]
pred_wrong = ['Positive' if y_preds[int(i)] == 1 else 'Negative' for i in wrong_indexes[:10]]
conf_wrong = [y_pred_probs[int(i)][0] for i in wrong_indexes[:10]]


wrong_df = pd.DataFrame({
    'Review': X_wrong_texts,
    'Actual Sentiment': actual_wrong,
    'Predicted Sentiment': pred_wrong,
    'Confidence Score': np.round(conf_wrong, 4)
})

print("\n❌ Wrong Predictions Sample:\n")
print(tabulate(wrong_df, headers='keys', tablefmt='fancy_grid', showindex=False))
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step
# 🔍 Classification Report:
#               precision    recall  f1-score   support
#
#     Negative       0.90      0.86      0.88      4961
#     Positive       0.87      0.91      0.89      5039
#
#     accuracy                           0.89     10000
#    macro avg       0.89      0.89      0.89     10000
# weighted avg       0.89      0.89      0.89     10000
# ❌ Wrong Predictions Sample:
#
# ...
